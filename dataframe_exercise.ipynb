# %% [markdown]
# <a href="https://colab.research.google.com/github/LiliannLucas/Practices/blob/main/dataframe_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read here first : https://realpython.com/pandas-dataframe/

# %% [markdown]
# 1. Create a dataframe like below:
#
# ![Screenshot 2021-07-06 at 9.08.27 PM.png](data:image/png;base64,...)

# %%
import pandas as pd  
  
data = {'Name': ['Liliann', 'Ji', 'Dan', 'Will', 'Tony', 'Kai', 'Jenny', 'Janice', 'Victor'], 'Last': ['Lucas', 'Lucas', 'Morris', 'Teddy', 'More', 'Tomma', 'Ohare', 'Mike', 'Moke'], 'Age': [17, 49, 34, 56, 44, 53, 32, 29, 5], 'Gender': ['Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male']}  
   
df = pd.DataFrame(data)  
 
print(df)
# Out:
#       Name    Last  Age  Gender
# 0  Liliann   Lucas   17  Female
# 1       Ji   Lucas   49  Female
# 2      Dan  Morris   34    Male
# 3     Will   Teddy   56    Male
# 4     Tony    More   44    Male
# 5      Kai   Tomma   53    Male
# 6    Jenny   Ohare   32  Female
# 7   Janice    Mike   29  Female
# 8   Victor    Moke    5    Male

# %% [markdown]
# 2. create a new column that contain full name

# %%
FullName = ['Liiann Lucas', 'Ji Lucas', 'Dan Morris', 'Will Teddy', 'Tony More', 'Kai Tomma', 'Jenny Ohare', 'Janice Mike', 'Victor Moke']

df['FullName'] = FullName

print(df)
# Out:
#       Name    Last  Age  Gender      FullName
# 0  Liliann   Lucas   17  Female  Liiann Lucas
# 1       Ji   Lucas   49  Female      Ji Lucas
# 2      Dan  Morris   34    Male    Dan Morris
# 3     Will   Teddy   56    Male    Will Teddy
# 4     Tony    More   44    Male     Tony More
# 5      Kai   Tomma   53    Male     Kai Tomma
# 6    Jenny   Ohare   32  Female   Jenny Ohare
# 7   Janice    Mike   29  Female   Janice Mike
# 8   Victor    Moke    5    Male   Victor Moke

# %% [markdown]
# 3. create a dataframe that contains only gender = male

# %%
# df.loc[lambda df: df['Gender'] == 'Male', :]

# df.loc[lambda df: df['Gender'] == 'Female', :]

# %%
df[df.Gender=='Male']

# df[df.Gender=='Female']
# Out:
#      Name    Last  Age Gender     FullName
# 2     Dan  Morris   34   Male   Dan Morris
# 3    Will   Teddy   56   Male   Will Teddy
# 4    Tony    More   44   Male    Tony More
# 5     Kai   Tomma   53   Male    Kai Tomma
# 8  Victor    Moke    5   Male  Victor Moke

# %% [markdown]
# 4. create a datafrane that cotains only age < 45

# %%
# df.astype({'Age': 'int32'}).dtypes

df.loc[lambda df: df['Age'] < 45]

df1 = df.loc[lambda df: df['Age'] < 45] 

df1
# Out:
#       Name    Last  Age  Gender      FullName
# 0  Liliann   Lucas   17  Female  Liiann Lucas
# 2      Dan  Morris   34    Male    Dan Morris
# 4     Tony    More   44    Male     Tony More
# 6    Jenny   Ohare   32  Female   Jenny Ohare
# 7   Janice    Mike   29  Female   Janice Mike
# 8   Victor    Moke    5    Male   Victor Moke

# %% [markdown]
# 5. find all rows from question 3 where rows exists in question 4

# %%
df1[df1.Gender=='Male']

df2 = df1[df1.Gender=='Male']

df2
# Out:
#      Name    Last  Age Gender     FullName
# 2     Dan  Morris   34   Male   Dan Morris
# 4    Tony    More   44   Male    Tony More
# 8  Victor    Moke    5   Male  Victor Moke

# %% [markdown]
# 6. save question 5 rows into csv file

# %%
df2.to_csv('df2.csv')

# %% [markdown]
# # New Section
